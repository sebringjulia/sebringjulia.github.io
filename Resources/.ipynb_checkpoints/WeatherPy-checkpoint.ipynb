# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# # Analysis
# 1) The temperature plot illustrates that cities near a latitude of 0 degrees have higher temperatures.
#
# 2) Windspeeds appear to be lower in cities in latitudes between 0 and 20 degrees.
#
# 3) Humidity tends to be high in cities in latitudes between -10 and 20 degrees.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pandas.io.json import json_normalize

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# JSON dependency
import json

# Path to base URL for API calls
base_URL = 'https://api.openweathermap.org/data/2.5/weather?q='

# Create list to store requested data
response = []

# Run successive API calls from first to final cities[1:-1]

for x in range(len(cities)):
    
    call = requests.get(base_URL + str(cities[x]) + "&APPID=" + api_key).json()
    
    #Exception handling for cities not recognized by weather API
    try:
        print(f"Requesting info for ID {call['id']}: {call['name']}...")
        response.append(call)
    except KeyError:
        pass
# Out:
# Requesting info for ID 6160362: Swan River...
# Requesting info for ID 6138908: Saint-Philippe...
# Requesting info for ID 3369157: Cape Town...
# Requesting info for ID 3471451: Arraial do Cabo...
# Requesting info for ID 1015776: Bredasdorp...
# Requesting info for ID 559731: Gornyy...
# Requesting info for ID 3896218: Castro...
# Requesting info for ID 2122090: Pevek...
# Requesting info for ID 2138285: Tadine...
# Requesting info for ID 3391287: Prainha...
# Requesting info for ID 3347019: Namibe...
# Requesting info for ID 5848280: Kapaa...
# Requesting info for ID 6201424: Mataura...
# Requesting info for ID 543508: Kovdor...
# Requesting info for ID 3833859: Barrow...
# Requesting info for ID 3874787: Punta Arenas...
# Requesting info for ID 2152659: Port Macquarie...
# Requesting info for ID 3418910: Upernavik...
# Requesting info for ID 6170031: Tuktoyaktuk...
# Requesting info for ID 5866063: Kenai...
# Requesting info for ID 3833367: Ushuaia...
# Requesting info for ID 1733782: Victoria...
# Requesting info for ID 2034228: Wangkui...
# Requesting info for ID 2069194: Jamestown...
# Requesting info for ID 3655185: Samana...
# Requesting info for ID 921028: Chadiza...
# Requesting info for ID 2127202: Anadyr...
# Requesting info for ID 107304: Buraydah...
# Requesting info for ID 5919850: Chapais...
# Requesting info for ID 4035715: Avarua...
# Requesting info for ID 3831208: Qaanaaq...
# Requesting info for ID 1259460: Pokaran...
# Requesting info for ID 259289: Corinth...
# Requesting info for ID 3443061: Chuy...
# Requesting info for ID 2163355: Hobart...
# Requesting info for ID 2656067: Broome...
# Requesting info for ID 4267710: Sitka...
# Requesting info for ID 5790966: Cosmopolis...
# Requesting info for ID 2377457: Nouadhibou...
# Requesting info for ID 2381334: Atar...
# Requesting info for ID 1253628: Lata...
# Requesting info for ID 5847411: Kahului...
# Requesting info for ID 2075265: Busselton...
# Requesting info for ID 2155415: New Norfolk...
# Requesting info for ID 5106834: Albany...
# Requesting info for ID 5350734: Fremont...
# Requesting info for ID 3985710: Cabo San Lucas...
# Requesting info for ID 780687: Berlevag...
# Requesting info for ID 3440777: Rocha...
# Requesting info for ID 1267390: Kavaratti...
# Requesting info for ID 1273574: Vaini...
# Requesting info for ID 5880568: Bethel...
# Requesting info for ID 2021017: Kysyl-Syr...
# Requesting info for ID 3412093: Vestmannaeyjar...
# Requesting info for ID 3533462: Acapulco...
# Requesting info for ID 3403687: Camocim...
# Requesting info for ID 4723422: Rockport...
# Requesting info for ID 2172880: Byron Bay...
# Requesting info for ID 1337616: Naifaru...
# Requesting info for ID 5850554: Makakilo City...
# Requesting info for ID 4494942: Thomasville...
# Requesting info for ID 1855612: Nara...
# Requesting info for ID 1701054: Marawi...
# Requesting info for ID 6184365: Woodstock...
# Requesting info for ID 3460826: Itamaraju...
# Requesting info for ID 1688696: San Policarpo...
# Requesting info for ID 1488206: Ust-Ishim...
# Requesting info for ID 3838859: Rio Gallegos...
# Requesting info for ID 5504003: Fernley...
# Requesting info for ID 1502280: Koyelga...
# Requesting info for ID 371745: Kutum...
# Requesting info for ID 2654970: Brae...
# Requesting info for ID 3393692: Itarema...
# Requesting info for ID 6255012: Flinders...
# Requesting info for ID 1795632: Shenjiamen...
# Requesting info for ID 2648372: Godalming...
# Requesting info for ID 3827693: La Macarena...
# Requesting info for ID 161974: Gazanjyk...
# Requesting info for ID 2014624: Udachnyy...
# Requesting info for ID 1635111: Puri...
# Requesting info for ID 1053384: Toamasina...
# Requesting info for ID 2165478: Gladstone...
# Requesting info for ID 2160063: Codrington...
# Requesting info for ID 2337542: Naze...
# Requesting info for ID 2274895: Monrovia...
# Requesting info for ID 3698359: Chicama...
# Requesting info for ID 1497337: Kayerkan...
# Requesting info for ID 4470244: Havelock...
# Requesting info for ID 1524325: Ekibastuz...
# Requesting info for ID 1489853: Tazovskiy...
# Requesting info for ID 3356264: Keetmanshoop...
# Requesting info for ID 945945: Upington...
# Requesting info for ID 2655984: Belfast...
# Requesting info for ID 3135601: Olden...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create dataframe based on the API responses
df = pd.DataFrame(response)
df.head()
# Out:
#        base       clouds  cod                           coord          dt  \
# 0  stations  {'all': 82}  200  {'lon': -101.27, 'lat': 52.11}  1570150432
# 1  stations  {'all': 90}  200   {'lon': -73.48, 'lat': 45.36}  1570150432
# 2  stations  {'all': 75}  200   {'lon': 18.42, 'lat': -33.93}  1570150433
# 3  stations  {'all': 40}  200  {'lon': -42.02, 'lat': -22.97}  1570150339
# 4  stations  {'all': 18}  200   {'lon': 20.04, 'lat': -34.53}  1570150434
#
#         id                                               main  \
# 0  6160362  {'temp': 276.335, 'pressure': 1023.48, 'humidi...
# 1  6138908  {'temp': 280.83, 'pressure': 1016, 'humidity':...
# 2  3369157  {'temp': 287.82, 'pressure': 1019, 'humidity':...
# 3  3471451  {'temp': 295.15, 'pressure': 1019, 'humidity':...
# 4  1015776  {'temp': 287.58, 'pressure': 1017, 'humidity':...
#
#               name rain snow  \
# 0       Swan River  NaN  NaN
# 1   Saint-Philippe  NaN  NaN
# 2        Cape Town  NaN  NaN
# 3  Arraial do Cabo  NaN  NaN
# 4       Bredasdorp  NaN  NaN
#
#                                                  sys  timezone  visibility  \
# 0  {'message': 0.0069, 'country': 'CA', 'sunrise'...    -18000         NaN
# 1  {'type': 1, 'id': 820, 'message': 0.0073, 'cou...    -14400     14484.0
# 2  {'type': 1, 'id': 1899, 'message': 0.0058, 'co...      7200     10000.0
# 3  {'type': 1, 'id': 8343, 'message': 0.0064, 'co...    -10800     10000.0
# 4  {'type': 1, 'id': 1966, 'message': 0.0062, 'co...      7200         NaN
#
#                                              weather  \
# 0  [{'id': 803, 'main': 'Clouds', 'description': ...
# 1  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 2  [{'id': 803, 'main': 'Clouds', 'description': ...
# 3  [{'id': 802, 'main': 'Clouds', 'description': ...
# 4  [{'id': 801, 'main': 'Clouds', 'description': ...
#
#                               wind
# 0  {'speed': 2.39, 'deg': 195.959}
# 1        {'speed': 4.1, 'deg': 50}
# 2       {'speed': 3.1, 'deg': 350}
# 3        {'speed': 6.2, 'deg': 60}
# 4       {'speed': 1.5, 'deg': 360}

# %%
response
# Out:
# [{'coord': {'lon': -101.27, 'lat': 52.11},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 276.335,
#    'pressure': 1023.48,
#    'humidity': 80,
#    'temp_min': 276.335,
#    'temp_max': 276.335,
#    'sea_level': 1023.48,
#    'grnd_level': 938.53},
#   'wind': {'speed': 2.39, 'deg': 195.959},
#   'clouds': {'all': 82},
#   'dt': 1570150432,
#   'sys': {'message': 0.0069,
#    'country': 'CA',
#    'sunrise': 1570106941,
#    'sunset': 1570148345},
#   'timezone': -18000,
#   'id': 6160362,
#   'name': 'Swan River',
#   'cod': 200},
#  {'coord': {'lon': -73.48, 'lat': 45.36},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 280.83,
#    'pressure': 1016,
#    'humidity': 70,
#    'temp_min': 279.26,
#    'temp_max': 282.15},
#   'visibility': 14484,
#   'wind': {'speed': 4.1, 'deg': 50},
#   'clouds': {'all': 90},
#   'dt': 1570150432,
#   'sys': {'type': 1,
#    'id': 820,
#    'message': 0.0073,
#    'country': 'CA',
#    'sunrise': 1570100047,
#    'sunset': 1570141902},
#   'timezone': -14400,
#   'id': 6138908,
#   'name': 'Saint-Philippe',
#   'cod': 200},
#  {'coord': {'lon': 18.42, 'lat': -33.93},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 287.82,
#    'pressure': 1019,
#    'humidity': 93,
#    'temp_min': 287.04,
#    'temp_max': 288.71},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 350},
#   'clouds': {'all': 75},
#   'dt': 1570150433,
#   'sys': {'type': 1,
#    'id': 1899,
#    'message': 0.0058,
#    'country': 'ZA',
#    'sunrise': 1570162781,
#    'sunset': 1570207828},
#   'timezone': 7200,
#   'id': 3369157,
#   'name': 'Cape Town',
#   'cod': 200},
#  {'coord': {'lon': -42.02, 'lat': -22.97},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 295.15,
#    'pressure': 1019,
#    'humidity': 88,
#    'temp_min': 295.15,
#    'temp_max': 295.15},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 60},
#   'clouds': {'all': 40},
#   'dt': 1570150339,
#   'sys': {'type': 1,
#    'id': 8343,
#    'message': 0.0064,
#    'country': 'BR',
#    'sunrise': 1570091212,
#    'sunset': 1570135640},
#   'timezone': -10800,
#   'id': 3471451,
#   'name': 'Arraial do Cabo',
#   'cod': 200},
#  {'coord': {'lon': 20.04, 'lat': -34.53},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 287.58,
#    'pressure': 1017,
#    'humidity': 82,
#    'temp_min': 286.15,
#    'temp_max': 288.71},
#   'wind': {'speed': 1.5, 'deg': 360},
#   'clouds': {'all': 18},
#   'dt': 1570150434,
#   'sys': {'type': 1,
#    'id': 1966,
#    'message': 0.0062,
#    'country': 'ZA',
#    'sunrise': 1570162375,
#    'sunset': 1570207456},
#   'timezone': 7200,
#   'id': 1015776,
#   'name': 'Bredasdorp',
#   'cod': 200},
#  {'coord': {'lon': 48.54, 'lat': 51.76},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 285.715,
#    'pressure': 1019.18,
#    'humidity': 79,
#    'temp_min': 285.715,
#    'temp_max': 285.715,
#    'sea_level': 1019.18,
#    'grnd_level': 1012.24},
#   'wind': {'speed': 3.84, 'deg': 168.868},
#   'clouds': {'all': 75},
#   'dt': 1570150434,
#   'sys': {'message': 0.0055,
#    'country': 'RU',
#    'sunrise': 1570157431,
#    'sunset': 1570198723},
#   'timezone': 14400,
#   'id': 559731,
#   'name': 'Gornyy',
#   'cod': 200},
#  {'coord': {'lon': -73.76, 'lat': -42.48},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 281.15,
#    'pressure': 1025,
#    'humidity': 75,
#    'temp_min': 281.15,
#    'temp_max': 281.15},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 220},
#   'clouds': {'all': 0},
#   'dt': 1570150435,
#   'sys': {'type': 1,
#    'id': 8512,
#    'message': 0.0056,
#    'country': 'CL',
#    'sunrise': 1570098305,
#    'sunset': 1570143779},
#   'timezone': -10800,
#   'id': 3896218,
#   'name': 'Castro',
#   'cod': 200},
#  {'coord': {'lon': 170.27, 'lat': 69.7},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 272.795,
#    'pressure': 999.07,
#    'humidity': 84,
#    'temp_min': 272.795,
#    'temp_max': 272.795,
#    'sea_level': 999.07,
#    'grnd_level': 998.48},
#   'wind': {'speed': 5.67, 'deg': 36.771},
#   'clouds': {'all': 100},
#   'dt': 1570150435,
#   'sys': {'message': 0.0067,
#    'country': 'RU',
#    'sunrise': 1570129334,
#    'sunset': 1570168403},
#   'timezone': 43200,
#   'id': 2122090,
#   'name': 'Pevek',
#   'cod': 200},
#  {'coord': {'lon': 167.88, 'lat': -21.55},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 293.855,
#    'pressure': 1018.97,
#    'humidity': 71,
#    'temp_min': 293.855,
#    'temp_max': 293.855,
#    'sea_level': 1018.97,
#    'grnd_level': 1019.02},
#   'wind': {'speed': 8.23, 'deg': 125.195},
#   'clouds': {'all': 100},
#   'dt': 1570150436,
#   'sys': {'message': 0.0068,
#    'country': 'NC',
#    'sunrise': 1570127242,
#    'sunset': 1570171642},
#   'timezone': 39600,
#   'id': 2138285,
#   'name': 'Tadine',
#   'cod': 200},
#  {'coord': {'lon': -53.48, 'lat': -1.8},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 301.455,
#    'pressure': 1010.76,
#    'humidity': 59,
#    'temp_min': 301.455,
#    'temp_max': 301.455,
#    'sea_level': 1010.76,
#    'grnd_level': 1008.97},
#   'wind': {'speed': 1.39, 'deg': 77.53},
#   'clouds': {'all': 71},
#   'dt': 1570150437,
#   'sys': {'message': 0.0065,
#    'country': 'BR',
#    'sunrise': 1570094346,
#    'sunset': 1570138005},
#   'timezone': -10800,
#   'id': 3391287,
#   'name': 'Prainha',
#   'cod': 200},
#  {'coord': {'lon': 12.15, 'lat': -15.19},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 291.605,
#    'pressure': 1012.19,
#    'humidity': 81,
#    'temp_min': 291.605,
#    'temp_max': 291.605,
#    'sea_level': 1012.19,
#    'grnd_level': 1012.25},
#   'wind': {'speed': 3.69, 'deg': 187.439},
#   'clouds': {'all': 65},
#   'dt': 1570150437,
#   'sys': {'message': 0.0064,
#    'country': 'AO',
#    'sunrise': 1570164726,
#    'sunset': 1570208891},
#   'timezone': 3600,
#   'id': 3347019,
#   'name': 'Namibe',
#   'cod': 200},
#  {'coord': {'lon': -159.32, 'lat': 22.08},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 302.15,
#    'pressure': 1016,
#    'humidity': 70,
#    'temp_min': 299.82,
#    'temp_max': 304.15},
#   'visibility': 16093,
#   'wind': {'speed': 7.2, 'deg': 50},
#   'rain': {'1h': 1.02},
#   'clouds': {'all': 75},
#   'dt': 1570150437,
#   'sys': {'type': 1,
#    'id': 7873,
#    'message': 0.0061,
#    'country': 'US',
#    'sunrise': 1570120148,
#    'sunset': 1570162995},
#   'timezone': -36000,
#   'id': 5848280,
#   'name': 'Kapaa',
#   'cod': 200},
#  {'coord': {'lon': 168.86, 'lat': -46.19},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 289.26,
#    'pressure': 1005,
#    'humidity': 60,
#    'temp_min': 289.26,
#    'temp_max': 289.26},
#   'wind': {'speed': 4.92, 'deg': 320, 'gust': 8.49},
#   'clouds': {'all': 100},
#   'dt': 1570150438,
#   'sys': {'type': 3,
#    'id': 2008959,
#    'message': 0.0062,
#    'country': 'NZ',
#    'sunrise': 1570126300,
#    'sunset': 1570172113},
#   'timezone': 46800,
#   'id': 6201424,
#   'name': 'Mataura',
#   'cod': 200},
#  {'coord': {'lon': 30.47, 'lat': 67.56},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 270.695,
#    'pressure': 1021.9,
#    'humidity': 96,
#    'temp_min': 270.695,
#    'temp_max': 270.695,
#    'sea_level': 1021.9,
#    'grnd_level': 998.17},
#   'wind': {'speed': 0.94, 'deg': 315.475},
#   'clouds': {'all': 0},
#   'dt': 1570150439,
#   'sys': {'message': 0.0073,
#    'country': 'RU',
#    'sunrise': 1570162742,
#    'sunset': 1570202083},
#   'timezone': 10800,
#   'id': 543508,
#   'name': 'Kovdor',
#   'cod': 200},
#  {'coord': {'lon': -60.23, 'lat': -38.31},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 280.125,
#    'pressure': 1029.14,
#    'humidity': 60,
#    'temp_min': 280.125,
#    'temp_max': 280.125,
#    'sea_level': 1029.14,
#    'grnd_level': 1017.55},
#   'wind': {'speed': 5.07, 'deg': 80.813},
#   'clouds': {'all': 100},
#   'dt': 1570150439,
#   'sys': {'message': 0.0049,
#    'country': 'AR',
#    'sunrise': 1570095197,
#    'sunset': 1570140394},
#   'timezone': -10800,
#   'id': 3833859,
#   'name': 'Barrow',
#   'cod': 200},
#  {'coord': {'lon': -70.91, 'lat': -53.16},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 278.92,
#    'pressure': 1007,
#    'humidity': 70,
#    'temp_min': 278.71,
#    'temp_max': 279.15},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 290},
#   'clouds': {'all': 75},
#   'dt': 1570150259,
#   'sys': {'type': 1,
#    'id': 8487,
#    'message': 0.0061,
#    'country': 'CL',
#    'sunrise': 1570097162,
#    'sunset': 1570143554},
#   'timezone': -10800,
#   'id': 3874787,
#   'name': 'Punta Arenas',
#   'cod': 200},
#  {'coord': {'lon': 152.91, 'lat': -31.43},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 301.07,
#    'pressure': 1019,
#    'humidity': 28,
#    'temp_min': 300.37,
#    'temp_max': 302.15},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 170},
#   'clouds': {'all': 0},
#   'dt': 1570150427,
#   'sys': {'type': 1,
#    'id': 9610,
#    'message': 0.0114,
#    'country': 'AU',
#    'sunrise': 1570130601,
#    'sunset': 1570175467},
#   'timezone': 36000,
#   'id': 2152659,
#   'name': 'Port Macquarie',
#   'cod': 200},
#  {'coord': {'lon': -56.15, 'lat': 72.79},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 276.525,
#    'pressure': 997.18,
#    'humidity': 74,
#    'temp_min': 276.525,
#    'temp_max': 276.525,
#    'sea_level': 997.18,
#    'grnd_level': 996.62},
#   'wind': {'speed': 4, 'deg': 341.361},
#   'clouds': {'all': 100},
#   'dt': 1570150259,
#   'sys': {'message': 0.0057,
#    'country': 'GL',
#    'sunrise': 1570097587,
#    'sunset': 1570136046},
#   'timezone': -7200,
#   'id': 3418910,
#   'name': 'Upernavik',
#   'cod': 200},
#  {'coord': {'lon': -133.03, 'lat': 69.44},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50n'}],
#   'base': 'stations',
#   'main': {'temp': 275.15,
#    'pressure': 1010,
#    'humidity': 100,
#    'temp_min': 275.15,
#    'temp_max': 275.15},
#   'visibility': 4828,
#   'wind': {'speed': 3.6, 'deg': 30},
#   'clouds': {'all': 90},
#   'dt': 1570150204,
#   'sys': {'type': 1,
#    'id': 942,
#    'message': 0.007,
#    'country': 'CA',
#    'sunrise': 1570115660,
#    'sunset': 1570154867},
#   'timezone': -21600,
#   'id': 6170031,
#   'name': 'Tuktoyaktuk',
#   'cod': 200},
#  {'coord': {'lon': -151.26, 'lat': 60.55},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 284.5,
#    'pressure': 1016,
#    'humidity': 54,
#    'temp_min': 283.15,
#    'temp_max': 285.15},
#   'visibility': 16093,
#   'wind': {'speed': 1.35, 'deg': 337.475},
#   'clouds': {'all': 40},
#   'dt': 1570150442,
#   'sys': {'type': 1,
#    'id': 7680,
#    'message': 0.0065,
#    'country': 'US',
#    'sunrise': 1570119341,
#    'sunset': 1570159934},
#   'timezone': -28800,
#   'id': 5866063,
#   'name': 'Kenai',
#   'cod': 200},
#  {'coord': {'lon': -68.31, 'lat': -54.81},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 280.15,
#    'pressure': 997,
#    'humidity': 56,
#    'temp_min': 280.15,
#    'temp_max': 280.15},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 270, 'gust': 11.3},
#   'clouds': {'all': 40},
#   'dt': 1570150424,
#   'sys': {'type': 1,
#    'id': 8303,
#    'message': 0.0077,
#    'country': 'AR',
#    'sunrise': 1570096446,
#    'sunset': 1570143022},
#   'timezone': -10800,
#   'id': 3833367,
#   'name': 'Ushuaia',
#   'cod': 200},
#  {'coord': {'lon': 115.24, 'lat': 5.28},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 297.82,
#    'pressure': 1013,
#    'humidity': 94,
#    'temp_min': 297.04,
#    'temp_max': 298.15},
#   'visibility': 10000,
#   'wind': {'speed': 4.07, 'deg': 55.635},
#   'clouds': {'all': 75},
#   'dt': 1570150443,
#   'sys': {'type': 1,
#    'id': 9372,
#    'message': 0.0066,
#    'country': 'BN',
#    'sunrise': 1570140363,
#    'sunset': 1570183782},
#   'timezone': 28800,
#   'id': 1733782,
#   'name': 'Victoria',
#   'cod': 200},
#  {'coord': {'lon': 126.5, 'lat': 46.83},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 277.875,
#    'pressure': 1026.7,
#    'humidity': 36,
#    'temp_min': 277.875,
#    'temp_max': 277.875,
#    'sea_level': 1026.7,
#    'grnd_level': 1001.57},
#   'wind': {'speed': 7.34, 'deg': 19.02},
#   'clouds': {'all': 100},
#   'dt': 1570150443,
#   'sys': {'message': 0.006,
#    'country': 'CN',
#    'sunrise': 1570138530,
#    'sunset': 1570180212},
#   'timezone': 28800,
#   'id': 2034228,
#   'name': 'Wangkui',
#   'cod': 200},
#  {'coord': {'lon': 138.6, 'lat': -33.21},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 298.145,
#    'pressure': 1021.72,
#    'humidity': 33,
#    'temp_min': 298.145,
#    'temp_max': 298.145,
#    'sea_level': 1021.72,
#    'grnd_level': 985.05},
#   'wind': {'speed': 4.68, 'deg': 39.299},
#   'clouds': {'all': 73},
#   'dt': 1570150339,
#   'sys': {'message': 0.0075,
#    'country': 'AU',
#    'sunrise': 1570133985,
#    'sunset': 1570178950},
#   'timezone': 34200,
#   'id': 2069194,
#   'name': 'Jamestown',
#   'cod': 200},
#  {'coord': {'lon': -76.97, 'lat': 0.12},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 295.085,
#    'pressure': 1015.08,
#    'humidity': 90,
#    'temp_min': 295.085,
#    'temp_max': 295.085,
#    'sea_level': 1015.08,
#    'grnd_level': 974.3},
#   'wind': {'speed': 1.06, 'deg': 159.933},
#   'clouds': {'all': 97},
#   'dt': 1570150444,
#   'sys': {'message': 0.0067,
#    'country': 'EC',
#    'sunrise': 1570100014,
#    'sunset': 1570143610},
#   'timezone': -18000,
#   'id': 3655185,
#   'name': 'Samana',
#   'cod': 200},
#  {'coord': {'lon': 32.43, 'lat': -14.06},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 291.635,
#    'pressure': 1016.07,
#    'humidity': 86,
#    'temp_min': 291.635,
#    'temp_max': 291.635,
#    'sea_level': 1016.07,
#    'grnd_level': 901.74},
#   'wind': {'speed': 4.24, 'deg': 137.188},
#   'clouds': {'all': 55},
#   'dt': 1570150444,
#   'sys': {'message': 0.0063,
#    'country': 'ZM',
#    'sunrise': 1570159884,
#    'sunset': 1570204002},
#   'timezone': 7200,
#   'id': 921028,
#   'name': 'Chadiza',
#   'cod': 200},
#  {'coord': {'lon': 177.51, 'lat': 64.73},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 268.91,
#    'pressure': 993,
#    'humidity': 79,
#    'temp_min': 268.71,
#    'temp_max': 269.15},
#   'visibility': 9000,
#   'wind': {'speed': 11, 'deg': 280, 'gust': 17},
#   'clouds': {'all': 40},
#   'dt': 1570150445,
#   'sys': {'type': 1,
#    'id': 8872,
#    'message': 0.0071,
#    'country': 'RU',
#    'sunrise': 1570127127,
#    'sunset': 1570167136},
#   'timezone': 43200,
#   'id': 2127202,
#   'name': 'Anadyr',
#   'cod': 200},
#  {'coord': {'lon': 43.97, 'lat': 26.33},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 302.15,
#    'pressure': 1012,
#    'humidity': 32,
#    'temp_min': 302.15,
#    'temp_max': 302.15},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 330},
#   'clouds': {'all': 0},
#   'dt': 1570150445,
#   'sys': {'type': 1,
#    'id': 7411,
#    'message': 0.0075,
#    'country': 'SA',
#    'sunrise': 1570157849,
#    'sunset': 1570200498},
#   'timezone': 10800,
#   'id': 107304,
#   'name': 'Buraydah',
#   'cod': 200},
#  {'coord': {'lon': -74.86, 'lat': 49.78},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 274.15,
#    'pressure': 1018,
#    'humidity': 74,
#    'temp_min': 274.15,
#    'temp_max': 274.15},
#   'visibility': 14484,
#   'wind': {'speed': 3.1, 'deg': 40},
#   'clouds': {'all': 90},
#   'dt': 1570150446,
#   'sys': {'type': 1,
#    'id': 859,
#    'message': 0.0065,
#    'country': 'CA',
#    'sunrise': 1570100514,
#    'sunset': 1570142098},
#   'timezone': -14400,
#   'id': 5919850,
#   'name': 'Chapais',
#   'cod': 200},
#  {'coord': {'lon': -159.78, 'lat': -21.21},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 299.15,
#    'pressure': 1013,
#    'humidity': 65,
#    'temp_min': 299.15,
#    'temp_max': 299.15},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 360},
#   'clouds': {'all': 72},
#   'dt': 1570150258,
#   'sys': {'type': 1,
#    'id': 7271,
#    'message': 0.0082,
#    'country': 'CK',
#    'sunrise': 1570119492,
#    'sunset': 1570163871},
#   'timezone': -36000,
#   'id': 4035715,
#   'name': 'Avarua',
#   'cod': 200},
#  {'coord': {'lon': -69.36, 'lat': 77.48},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 271.965,
#    'pressure': 1000.21,
#    'humidity': 58,
#    'temp_min': 271.965,
#    'temp_max': 271.965,
#    'sea_level': 1000.21,
#    'grnd_level': 961.44},
#   'wind': {'speed': 2.72, 'deg': 67.059},
#   'clouds': {'all': 91},
#   'dt': 1570150447,
#   'sys': {'message': 0.0079,
#    'country': 'GL',
#    'sunrise': 1570101745,
#    'sunset': 1570138227},
#   'timezone': -10800,
#   'id': 3831208,
#   'name': 'Qaanaaq',
#   'cod': 200},
#  {'coord': {'lon': 71.92, 'lat': 26.93},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 302.605,
#    'pressure': 1008.07,
#    'humidity': 54,
#    'temp_min': 302.605,
#    'temp_max': 302.605,
#    'sea_level': 1008.07,
#    'grnd_level': 984.77},
#   'wind': {'speed': 2.73, 'deg': 275.443},
#   'rain': {'3h': 0.938},
#   'clouds': {'all': 2},
#   'dt': 1570150447,
#   'sys': {'message': 0.0063,
#    'country': 'IN',
#    'sunrise': 1570151151,
#    'sunset': 1570193783},
#   'timezone': 19800,
#   'id': 1259460,
#   'name': 'Pokaran',
#   'cod': 200},
#  {'coord': {'lon': 22.93, 'lat': 37.94},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 293.88,
#    'pressure': 1009,
#    'humidity': 73,
#    'temp_min': 288.15,
#    'temp_max': 297.15},
#   'visibility': 10000,
#   'wind': {'speed': 2.73, 'deg': 227.922},
#   'clouds': {'all': 20},
#   'dt': 1570150448,
#   'sys': {'type': 1,
#    'id': 6613,
#    'message': 0.0079,
#    'country': 'GR',
#    'sunrise': 1570163158,
#    'sunset': 1570205286},
#   'timezone': 10800,
#   'id': 259289,
#   'name': 'Corinth',
#   'cod': 200},
#  {'coord': {'lon': -53.46, 'lat': -33.69},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 287.475,
#    'pressure': 1026.64,
#    'humidity': 81,
#    'temp_min': 287.475,
#    'temp_max': 287.475,
#    'sea_level': 1026.64,
#    'grnd_level': 1026.45},
#   'wind': {'speed': 4.29, 'deg': 90.28},
#   'clouds': {'all': 60},
#   'dt': 1570150270,
#   'sys': {'message': 0.0062,
#    'country': 'UY',
#    'sunrise': 1570093704,
#    'sunset': 1570138637},
#   'timezone': -10800,
#   'id': 3443061,
#   'name': 'Chuy',
#   'cod': 200},
#  {'coord': {'lon': 147.33, 'lat': -42.88},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 286.48,
#    'pressure': 1017,
#    'humidity': 44,
#    'temp_min': 285.37,
#    'temp_max': 287.59},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 300},
#   'clouds': {'all': 75},
#   'dt': 1570150255,
#   'sys': {'type': 1,
#    'id': 9545,
#    'message': 0.0063,
#    'country': 'AU',
#    'sunrise': 1570131588,
#    'sunset': 1570177157},
#   'timezone': 36000,
#   'id': 2163355,
#   'name': 'Hobart',
#   'cod': 200},
#  {'coord': {'lon': 1.45, 'lat': 52.47},
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': 'heavy intensity rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 284.03,
#    'pressure': 1005,
#    'humidity': 100,
#    'temp_min': 283.15,
#    'temp_max': 285.37},
#   'visibility': 2300,
#   'wind': {'speed': 5.7, 'deg': 170},
#   'clouds': {'all': 100},
#   'dt': 1570150449,
#   'sys': {'type': 1,
#    'id': 1467,
#    'message': 0.0079,
#    'country': 'GB',
#    'sunrise': 1570168774,
#    'sunset': 1570209978},
#   'timezone': 3600,
#   'id': 2656067,
#   'name': 'Broome',
#   'cod': 200},
#  {'coord': {'lon': -99.65, 'lat': 37.17},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 286.21,
#    'pressure': 973,
#    'humidity': 77,
#    'temp_min': 285.93,
#    'temp_max': 286.48},
#   'wind': {'speed': 3.13, 'deg': 263, 'gust': 5.81},
#   'clouds': {'all': 89},
#   'dt': 1570150450,
#   'sys': {'type': 3,
#    'id': 2021131,
#    'message': 0.0072,
#    'country': 'US',
#    'sunrise': 1570106124,
#    'sunset': 1570148384},
#   'timezone': -18000,
#   'id': 4267710,
#   'name': 'Sitka',
#   'cod': 200},
#  {'coord': {'lon': -123.77, 'lat': 46.96},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 284.98,
#    'pressure': 1016,
#    'humidity': 87,
#    'temp_min': 283.15,
#    'temp_max': 286.48},
#   'visibility': 11265,
#   'wind': {'speed': 4.1, 'deg': 180},
#   'rain': {'1h': 0.93},
#   'clouds': {'all': 90},
#   'dt': 1570150450,
#   'sys': {'type': 1,
#    'id': 4406,
#    'message': 0.0081,
#    'country': 'US',
#    'sunrise': 1570112174,
#    'sunset': 1570153909},
#   'timezone': -25200,
#   'id': 5790966,
#   'name': 'Cosmopolis',
#   'cod': 200},
#  {'coord': {'lon': -17.03, 'lat': 20.93},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 300.15,
#    'pressure': 1012,
#    'humidity': 51,
#    'temp_min': 300.15,
#    'temp_max': 300.15},
#   'visibility': 7000,
#   'wind': {'speed': 9.8, 'deg': 20},
#   'clouds': {'all': 5},
#   'dt': 1570150450,
#   'sys': {'type': 1,
#    'id': 2444,
#    'message': 0.0074,
#    'country': 'MR',
#    'sunrise': 1570172388,
#    'sunset': 1570215233},
#   'timezone': 0,
#   'id': 2377457,
#   'name': 'Nouadhibou',
#   'cod': 200},
#  {'coord': {'lon': -13.05, 'lat': 20.52},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 306.275,
#    'pressure': 1010.91,
#    'humidity': 12,
#    'temp_min': 306.275,
#    'temp_max': 306.275,
#    'sea_level': 1010.91,
#    'grnd_level': 993.58},
#   'wind': {'speed': 6.73, 'deg': 18.831},
#   'clouds': {'all': 13},
#   'dt': 1570150451,
#   'sys': {'message': 0.0075,
#    'country': 'MR',
#    'sunrise': 1570171424,
#    'sunset': 1570214286},
#   'timezone': 0,
#   'id': 2381334,
#   'name': 'Atar',
#   'cod': 200},
#  {'coord': {'lon': 78.62, 'lat': 30.78},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 272.745,
#    'pressure': 1018.01,
#    'humidity': 83,
#    'temp_min': 272.745,
#    'temp_max': 272.745,
#    'sea_level': 1018.01,
#    'grnd_level': 634.06},
#   'wind': {'speed': 1.48, 'deg': 55.527},
#   'clouds': {'all': 99},
#   'dt': 1570150452,
#   'sys': {'message': 0.0055,
#    'country': 'IN',
#    'sunrise': 1570149621,
#    'sunset': 1570192098},
#   'timezone': 19800,
#   'id': 1253628,
#   'name': 'Lata',
#   'cod': 200},
#  {'coord': {'lon': -156.47, 'lat': 20.89},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 301.22,
#    'pressure': 1014,
#    'humidity': 52,
#    'temp_min': 298.71,
#    'temp_max': 305.15},
#   'visibility': 16093,
#   'wind': {'speed': 10.3, 'deg': 50, 'gust': 14.4},
#   'clouds': {'all': 40},
#   'dt': 1570150453,
#   'sys': {'type': 1,
#    'id': 7879,
#    'message': 0.0062,
#    'country': 'US',
#    'sunrise': 1570119443,
#    'sunset': 1570162333},
#   'timezone': -36000,
#   'id': 5847411,
#   'name': 'Kahului',
#   'cod': 200},
#  {'coord': {'lon': 115.35, 'lat': -33.64},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 288.27,
#    'pressure': 1001,
#    'humidity': 56,
#    'temp_min': 286.48,
#    'temp_max': 290.93},
#   'wind': {'speed': 10.62, 'deg': 25.974},
#   'rain': {'3h': 3.562},
#   'clouds': {'all': 94},
#   'dt': 1570150250,
#   'sys': {'type': 3,
#    'id': 2011706,
#    'message': 0.0077,
#    'country': 'AU',
#    'sunrise': 1570139548,
#    'sunset': 1570184545},
#   'timezone': 28800,
#   'id': 2075265,
#   'name': 'Busselton',
#   'cod': 200},
#  {'coord': {'lon': 147.06, 'lat': -42.78},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 286.49,
#    'pressure': 1017,
#    'humidity': 44,
#    'temp_min': 285.37,
#    'temp_max': 287.59},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 300},
#   'clouds': {'all': 75},
#   'dt': 1570150453,
#   'sys': {'type': 1,
#    'id': 9545,
#    'message': 0.0062,
#    'country': 'AU',
#    'sunrise': 1570131657,
#    'sunset': 1570177218},
#   'timezone': 36000,
#   'id': 2155415,
#   'name': 'New Norfolk',
#   'cod': 200},
#  {'coord': {'lon': -73.75, 'lat': 42.65},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}],
#   'base': 'stations',
#   'main': {'temp': 281.69,
#    'pressure': 1017,
#    'humidity': 87,
#    'temp_min': 279.82,
#    'temp_max': 283.15},
#   'visibility': 8047,
#   'wind': {'speed': 3.1, 'deg': 150},
#   'rain': {'1h': 0.42},
#   'clouds': {'all': 90},
#   'dt': 1570150448,
#   'sys': {'type': 1,
#    'id': 3273,
#    'message': 0.0092,
#    'country': 'US',
#    'sunrise': 1570100038,
#    'sunset': 1570142041},
#   'timezone': -14400,
#   'id': 5106834,
#   'name': 'Albany',
#   'cod': 200},
#  {'coord': {'lon': -121.99, 'lat': 37.55},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 291.12,
#    'pressure': 1016,
#    'humidity': 63,
#    'temp_min': 288.15,
#    'temp_max': 294.15},
#   'visibility': 16093,
#   'wind': {'speed': 6.2, 'deg': 250},
#   'clouds': {'all': 1},
#   'dt': 1570150454,
#   'sys': {'type': 1,
#    'id': 4446,
#    'message': 0.0102,
#    'country': 'US',
#    'sunrise': 1570111498,
#    'sunset': 1570153731},
#   'timezone': -25200,
#   'id': 5350734,
#   'name': 'Fremont',
#   'cod': 200},
#  {'coord': {'lon': -109.91, 'lat': 22.89},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 300.49,
#    'pressure': 1012,
#    'humidity': 61,
#    'temp_min': 298.71,
#    'temp_max': 302.04},
#   'visibility': 16093,
#   'wind': {'speed': 5.7, 'deg': 250},
#   'clouds': {'all': 20},
#   'dt': 1570150353,
#   'sys': {'type': 1,
#    'id': 7151,
#    'message': 0.0073,
#    'country': 'MX',
#    'sunrise': 1570108302,
#    'sunset': 1570151130},
#   'timezone': -21600,
#   'id': 3985710,
#   'name': 'Cabo San Lucas',
#   'cod': 200},
#  {'coord': {'lon': 29.09, 'lat': 70.86},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 277.445,
#    'pressure': 1020.87,
#    'humidity': 77,
#    'temp_min': 277.445,
#    'temp_max': 277.445,
#    'sea_level': 1020.87,
#    'grnd_level': 1019.97},
#   'wind': {'speed': 6.97, 'deg': 328.806},
#   'clouds': {'all': 95},
#   'dt': 1570150455,
#   'sys': {'message': 0.0081,
#    'country': 'NO',
#    'sunrise': 1570163458,
#    'sunset': 1570202030},
#   'timezone': 7200,
#   'id': 780687,
#   'name': 'Berlevag',
#   'cod': 200},
#  {'coord': {'lon': -54.34, 'lat': -34.48},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 284.425,
#    'pressure': 1026.94,
#    'humidity': 85,
#    'temp_min': 284.425,
#    'temp_max': 284.425,
#    'sea_level': 1026.94,
#    'grnd_level': 1013.95},
#   'wind': {'speed': 3.66, 'deg': 96.128},
#   'clouds': {'all': 45},
#   'dt': 1570150456,
#   'sys': {'message': 0.0062,
#    'country': 'UY',
#    'sunrise': 1570093894,
#    'sunset': 1570138870},
#   'timezone': -10800,
#   'id': 3440777,
#   'name': 'Rocha',
#   'cod': 200},
#  {'coord': {'lon': 72.64, 'lat': 10.57},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 300.725,
#    'pressure': 1010.05,
#    'humidity': 71,
#    'temp_min': 300.725,
#    'temp_max': 300.725,
#    'sea_level': 1010.05,
#    'grnd_level': 1010.19},
#   'wind': {'speed': 1.61, 'deg': 279.263},
#   'clouds': {'all': 58},
#   'dt': 1570150260,
#   'sys': {'message': 0.0067,
#    'country': 'IN',
#    'sunrise': 1570150678,
#    'sunset': 1570193911},
#   'timezone': 19800,
#   'id': 1267390,
#   'name': 'Kavaratti',
#   'cod': 200},
#  {'coord': {'lon': 74.49, 'lat': 15.34},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 293.15,
#    'pressure': 1016,
#    'humidity': 100,
#    'temp_min': 293.15,
#    'temp_max': 293.15},
#   'visibility': 6000,
#   'wind': {'speed': 0.93, 'deg': 53.869},
#   'clouds': {'all': 75},
#   'dt': 1570150457,
#   'sys': {'type': 1,
#    'id': 9229,
#    'message': 0.0079,
#    'country': 'IN',
#    'sunrise': 1570150317,
#    'sunset': 1570193384},
#   'timezone': 19800,
#   'id': 1273574,
#   'name': 'Vaini',
#   'cod': 200},
#  {'coord': {'lon': -161.76, 'lat': 60.79},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 282.15,
#    'pressure': 1011,
#    'humidity': 81,
#    'temp_min': 282.15,
#    'temp_max': 282.15},
#   'visibility': 16093,
#   'wind': {'speed': 7.2, 'deg': 210, 'gust': 12.3},
#   'clouds': {'all': 90},
#   'dt': 1570150290,
#   'sys': {'type': 1,
#    'id': 7640,
#    'message': 0.0084,
#    'country': 'US',
#    'sunrise': 1570121879,
#    'sunset': 1570162435},
#   'timezone': -28800,
#   'id': 5880568,
#   'name': 'Bethel',
#   'cod': 200},
#  {'coord': {'lon': 122.77, 'lat': 63.9},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 271.795,
#    'pressure': 1011.91,
#    'humidity': 94,
#    'temp_min': 271.795,
#    'temp_max': 271.795,
#    'sea_level': 1011.91,
#    'grnd_level': 992.73},
#   'wind': {'speed': 3.47, 'deg': 117.896},
#   'clouds': {'all': 100},
#   'dt': 1570150457,
#   'sys': {'message': 0.0079,
#    'country': 'RU',
#    'sunrise': 1570140229,
#    'sunset': 1570180303},
#   'timezone': 32400,
#   'id': 2021017,
#   'name': 'Kysyl-Syr',
#   'cod': 200},
#  {'coord': {'lon': -20.27, 'lat': 63.44},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 281.985,
#    'pressure': 1010.28,
#    'humidity': 78,
#    'temp_min': 281.985,
#    'temp_max': 281.985,
#    'sea_level': 1010.28,
#    'grnd_level': 1009.61},
#   'wind': {'speed': 19.18, 'deg': 111.158},
#   'clouds': {'all': 100},
#   'dt': 1570150458,
#   'sys': {'message': 0.0063,
#    'country': 'IS',
#    'sunrise': 1570174592,
#    'sunset': 1570214583},
#   'timezone': 0,
#   'id': 3412093,
#   'name': 'Vestmannaeyjar',
#   'cod': 200},
#  {'coord': {'lon': -99.88, 'lat': 16.86},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 302.15,
#    'pressure': 1010,
#    'humidity': 74,
#    'temp_min': 302.15,
#    'temp_max': 302.15},
#   'visibility': 12874,
#   'wind': {'speed': 0.82, 'deg': 237.341},
#   'clouds': {'all': 40},
#   'dt': 1570150458,
#   'sys': {'type': 1,
#    'id': 7103,
#    'message': 0.0074,
#    'country': 'MX',
#    'sunrise': 1570105789,
#    'sunset': 1570148830},
#   'timezone': -18000,
#   'id': 3533462,
#   'name': 'Acapulco',
#   'cod': 200},
#  {'coord': {'lon': -40.84, 'lat': -2.9},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 297.185,
#    'pressure': 1012.91,
#    'humidity': 82,
#    'temp_min': 297.185,
#    'temp_max': 297.185,
#    'sea_level': 1012.91,
#    'grnd_level': 1009.71},
#   'wind': {'speed': 2.18, 'deg': 95.287},
#   'clouds': {'all': 0},
#   'dt': 1570150459,
#   'sys': {'message': 0.0057,
#    'country': 'BR',
#    'sunrise': 1570091295,
#    'sunset': 1570134990},
#   'timezone': -10800,
#   'id': 3403687,
#   'name': 'Camocim',
#   'cod': 200},
#  {'coord': {'lon': -173.23, 'lat': 64.42},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 278.15,
#    'pressure': 993,
#    'humidity': 86,
#    'temp_min': 278.15,
#    'temp_max': 278.15},
#   'visibility': 10000,
#   'wind': {'speed': 9, 'deg': 250, 'gust': 14},
#   'clouds': {'all': 90},
#   'dt': 1570150434,
#   'sys': {'type': 1,
#    'id': 8875,
#    'message': 0.0065,
#    'country': 'RU',
#    'sunrise': 1570211453,
#    'sunset': 1570251127},
#   'timezone': 43200,
#   'id': 4031574,
#   'name': 'Provideniya',
#   'cod': 200},
#  {'coord': {'lon': -7.35, 'lat': 40.36},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 287.58,
#    'pressure': 1020,
#    'humidity': 75,
#    'temp_min': 287.04,
#    'temp_max': 288.15},
#   'wind': {'speed': 0.71, 'deg': 286.358},
#   'clouds': {'all': 0},
#   'dt': 1570150460,
#   'sys': {'type': 3,
#    'id': 2018935,
#    'message': 0.0063,
#    'country': 'PT',
#    'sunrise': 1570170493,
#    'sunset': 1570212483},
#   'timezone': 3600,
#   'id': 8010472,
#   'name': 'Belmonte',
#   'cod': 200},
#  {'coord': {'lon': 29.48, 'lat': -3.48},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 284.035,
#    'pressure': 1011.98,
#    'humidity': 90,
#    'temp_min': 284.035,
#    'temp_max': 284.035,
#    'sea_level': 1011.98,
#    'grnd_level': 757.36},
#   'wind': {'speed': 1.59, 'deg': 115.434},
#   'clouds': {'all': 0},
#   'dt': 1570150326,
#   'sys': {'message': 0.0058,
#    'country': 'BI',
#    'sunrise': 1570160789,
#    'sunset': 1570204512},
#   'timezone': 7200,
#   'id': 425378,
#   'name': 'Matara',
#   'cod': 200},
#  {'coord': {'lon': 0.99, 'lat': 5.92},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 298.15,
#    'pressure': 1012,
#    'humidity': 94,
#    'temp_min': 298.15,
#    'temp_max': 298.15},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 250},
#   'clouds': {'all': 40},
#   'dt': 1570150461,
#   'sys': {'type': 1,
#    'id': 1218,
#    'message': 0.0066,
#    'country': 'GH',
#    'sunrise': 1570167791,
#    'sunset': 1570211182},
#   'timezone': 0,
#   'id': 2299645,
#   'name': 'Keta',
#   'cod': 200},
#  {'coord': {'lon': 80.65, 'lat': 7.87},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 296.805,
#    'pressure': 1010.74,
#    'humidity': 91,
#    'temp_min': 296.805,
#    'temp_max': 296.805,
#    'sea_level': 1010.74,
#    'grnd_level': 994.19},
#   'wind': {'speed': 1.02, 'deg': 204.179},
#   'clouds': {'all': 73},
#   'dt': 1570150461,
#   'sys': {'message': 0.0073,
#    'country': 'LK',
#    'sunrise': 1570148709,
#    'sunset': 1570192036},
#   'timezone': 19800,
#   'id': 1248749,
#   'name': 'Dambulla',
#   'cod': 200},
#  {'coord': {'lon': 18.72, 'lat': 63.29},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 274.6,
#    'pressure': 1019,
#    'humidity': 55,
#    'temp_min': 274.15,
#    'temp_max': 275.15},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 10},
#   'clouds': {'all': 25},
#   'dt': 1570150462,
#   'sys': {'type': 1,
#    'id': 1768,
#    'message': 0.0077,
#    'country': 'SE',
#    'sunrise': 1570165205,
#    'sunset': 1570205259},
#   'timezone': 7200,
#   'id': 2686469,
#   'name': 'Ornskoldsvik',
#   'cod': 200},
#  {'coord': {'lon': 126.7, 'lat': 62.1},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 270.555,
#    'pressure': 1015.44,
#    'humidity': 75,
#    'temp_min': 270.555,
#    'temp_max': 270.555,
#    'sea_level': 1015.44,
#    'grnd_level': 984.27},
#   'wind': {'speed': 2.81, 'deg': 156.236},
#   'clouds': {'all': 94},
#   'dt': 1570150462,
#   'sys': {'message': 0.0067,
#    'country': 'RU',
#    'sunrise': 1570139160,
#    'sunset': 1570179486},
#   'timezone': 32400,
#   'id': 2026861,
#   'name': 'Berdigestyakh',
#   'cod': 200},
#  {'coord': {'lon': 83.99, 'lat': 28.21},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 281.985,
#    'pressure': 1016.88,
#    'humidity': 69,
#    'temp_min': 281.985,
#    'temp_max': 281.985,
#    'sea_level': 1016.88,
#    'grnd_level': 742.88},
#   'wind': {'speed': 2.05, 'deg': 7.358},
#   'clouds': {'all': 0},
#   'dt': 1570150301,
#   'sys': {'message': 0.0052,
#    'country': 'NP',
#    'sunrise': 1570148279,
#    'sunset': 1570190863},
#   'timezone': 20700,
#   'id': 1282898,
#   'name': 'Pokhara',
#   'cod': 200},
#  {'coord': {'lon': -52.73, 'lat': 47.66},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 277.11,
#    'pressure': 1008,
#    'humidity': 69,
#    'temp_min': 276.48,
#    'temp_max': 278.15},
#   'visibility': 24140,
#   'wind': {'speed': 6.2, 'deg': 320},
#   'clouds': {'all': 75},
#   'dt': 1570150463,
#   'sys': {'type': 1,
#    'id': 998,
#    'message': 0.0067,
#    'country': 'CA',
#    'sunrise': 1570095130,
#    'sunset': 1570136862},
#   'timezone': -9000,
#   'id': 6167817,
#   'name': 'Torbay',
#   'cod': 200},
#  {'coord': {'lon': 5.47, 'lat': 10.4},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 295.905,
#    'pressure': 1011.49,
#    'humidity': 92,
#    'temp_min': 295.905,
#    'temp_max': 295.905,
#    'sea_level': 1011.49,
#    'grnd_level': 979.81},
#   'wind': {'speed': 3.63, 'deg': 155.037},
#   'rain': {'3h': 2.876},
#   'clouds': {'all': 90},
#   'dt': 1570150463,
#   'sys': {'message': 0.0058,
#    'country': 'NG',
#    'sunrise': 1570166795,
#    'sunset': 1570210028},
#   'timezone': 3600,
#   'id': 2334008,
#   'name': 'Kontagora',
#   'cod': 200},
#  {'coord': {'lon': 30.79, 'lat': 59.7},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 276.35,
#    'pressure': 1004,
#    'humidity': 86,
#    'temp_min': 275.37,
#    'temp_max': 277.15},
#   'visibility': 7000,
#   'wind': {'speed': 3, 'deg': 10},
#   'clouds': {'all': 90},
#   'dt': 1570150464,
#   'sys': {'type': 1,
#    'id': 8926,
#    'message': 0.0065,
#    'country': 'RU',
#    'sunrise': 1570162071,
#    'sunset': 1570202601},
#   'timezone': 10800,
#   'id': 546105,
#   'name': 'Nikolskoye',
#   'cod': 200},
#  {'coord': {'lon': -74.98, 'lat': 39.31},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50n'},
#    {'id': 300,
#     'main': 'Drizzle',
#     'description': 'light intensity drizzle',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 292.04,
#    'pressure': 1015,
#    'humidity': 100,
#    'temp_min': 289.26,
#    'temp_max': 294.82},
#   'visibility': 8047,
#   'wind': {'speed': 2.1, 'deg': 110},
#   'clouds': {'all': 90},
#   'dt': 1570150464,
#   'sys': {'type': 1,
#    'id': 9745,
#    'message': 0.0097,
#    'country': 'US',
#    'sunrise': 1570100250,
#    'sunset': 1570142419},
#   'timezone': -14400,
#   'id': 4501427,
#   'name': 'Port Elizabeth',
#   'cod': 200},
#  {'coord': {'lon': 150.67, 'lat': -10.62},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 297.535,
#    'pressure': 1012.44,
#    'humidity': 93,
#    'temp_min': 297.535,
#    'temp_max': 297.535,
#    'sea_level': 1012.44,
#    'grnd_level': 997.97},
#   'wind': {'speed': 4, 'deg': 139.961},
#   'rain': {'3h': 3.374},
#   'clouds': {'all': 99},
#   'dt': 1570150465,
#   'sys': {'message': 0.0063,
#    'country': 'PG',
#    'sunrise': 1570131584,
#    'sunset': 1570175558},
#   'timezone': 36000,
#   'id': 2132606,
#   'name': 'Samarai',
#   'cod': 200},
#  {'coord': {'lon': 94.8, 'lat': 28.17},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 284.975,
#    'pressure': 1015.88,
#    'humidity': 93,
#    'temp_min': 284.975,
#    'temp_max': 284.975,
#    'sea_level': 1015.88,
#    'grnd_level': 800.21},
#   'wind': {'speed': 2.4, 'deg': 296.139},
#   'clouds': {'all': 20},
#   'dt': 1570150465,
#   'sys': {'message': 0.0074,
#    'country': 'IN',
#    'sunrise': 1570145683,
#    'sunset': 1570188272},
#   'timezone': 19800,
#   'id': 1278969,
#   'name': 'Along',
#   'cod': 200},
#  {'coord': {'lon': 140.83, 'lat': 35.73},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 294.96,
#    'pressure': 1006,
#    'humidity': 94,
#    'temp_min': 294.26,
#    'temp_max': 295.37},
#   'visibility': 8000,
#   'wind': {'speed': 6.7, 'deg': 180},
#   'clouds': {'all': 75},
#   'dt': 1570150213,
#   'sys': {'type': 1,
#    'id': 7955,
#    'message': 0.0102,
#    'country': 'JP',
#    'sunrise': 1570134793,
#    'sunset': 1570177072},
#   'timezone': 32400,
#   'id': 2112802,
#   'name': 'Hasaki',
#   'cod': 200},
#  {'coord': {'lon': 108.54, 'lat': -7.37},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 297.245,
#    'pressure': 1014.06,
#    'humidity': 79,
#    'temp_min': 297.245,
#    'temp_max': 297.245,
#    'sea_level': 1014.06,
#    'grnd_level': 989.25},
#   'wind': {'speed': 1.34, 'deg': 150.891},
#   'rain': {'3h': 0.188},
#   'clouds': {'all': 64},
#   'dt': 1570150467,
#   'sys': {'message': 0.0067,
#    'country': 'ID',
#    'sunrise': 1570141751,
#    'sunset': 1570185610},
#   'timezone': 25200,
#   'id': 1650233,
#   'name': 'Banjar',
#   'cod': 200},
#  {'coord': {'lon': 19.24, 'lat': -34.42},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 288.09,
#    'pressure': 1012,
#    'humidity': 79,
#    'temp_min': 287.59,
#    'temp_max': 288.71},
#   'wind': {'speed': 1.34, 'deg': 298, 'gust': 4.02},
#   'rain': {'3h': 0.062},
#   'clouds': {'all': 51},
#   'dt': 1570150193,
#   'sys': {'type': 3,
#    'id': 2006131,
#    'message': 0.0082,
#    'country': 'ZA',
#    'sunrise': 1570162570,
#    'sunset': 1570207645},
#   'timezone': 7200,
#   'id': 3366880,
#   'name': 'Hermanus',
#   'cod': 200},
#  {'coord': {'lon': 4.24, 'lat': 48.95},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 281.1,
#    'pressure': 1013,
#    'humidity': 93,
#    'temp_min': 278.71,
#    'temp_max': 282.59},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 170},
#   'clouds': {'all': 0},
#   'dt': 1570150468,
#   'sys': {'type': 1,
#    'id': 6535,
#    'message': 0.0059,
#    'country': 'FR',
#    'sunrise': 1570167971,
#    'sunset': 1570209442},
#   'timezone': 7200,
#   'id': 2995603,
#   'name': 'Saint-Pierre',
#   'cod': 200},
#  {'coord': {'lon': -46.02, 'lat': -1.2},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 299.305,
#    'pressure': 1012.88,
#    'humidity': 77,
#    'temp_min': 299.305,
#    'temp_max': 299.305,
#    'sea_level': 1012.88,
#    'grnd_level': 1011.87},
#   'wind': {'speed': 4.02, 'deg': 71.272},
#   'clouds': {'all': 11},
#   'dt': 1570150468,
#   'sys': {'message': 0.0063,
#    'country': 'BR',
#    'sunrise': 1570092566,
#    'sunset': 1570136205},
#   'timezone': -10800,
#   'id': 3402648,
#   'name': 'Carutapera',
#   'cod': 200},
#  {'coord': {'lon': 121.89, 'lat': -33.86},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 287.15,
#    'pressure': 1017,
#    'humidity': 82,
#    'temp_min': 287.15,
#    'temp_max': 287.15},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 60},
#   'clouds': {'all': 90},
#   'dt': 1570150434,
#   'sys': {'type': 1,
#    'id': 9525,
#    'message': 0.0079,
#    'country': 'AU',
#    'sunrise': 1570137974,
#    'sunset': 1570182980},
#   'timezone': 28800,
#   'id': 2071860,
#   'name': 'Esperance',
#   'cod': 200},
#  {'coord': {'lon': -111.68, 'lat': 43.97},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 287.76,
#    'pressure': 1014,
#    'humidity': 36,
#    'temp_min': 285.37,
#    'temp_max': 289.15},
#   'visibility': 16093,
#   'wind': {'speed': 1.97, 'deg': 317.281},
#   'clouds': {'all': 1},
#   'dt': 1570150469,
#   'sys': {'type': 1,
#    'id': 5735,
#    'message': 0.0069,
#    'country': 'US',
#    'sunrise': 1570109184,
#    'sunset': 1570151097},
#   'timezone': -21600,
#   'id': 5606187,
#   'name': 'Saint Anthony',
#   'cod': 200},
#  {'coord': {'lon': 73.08, 'lat': -0.6},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 301.045,
#    'pressure': 1010.08,
#    'humidity': 78,
#    'temp_min': 301.045,
#    'temp_max': 301.045,
#    'sea_level': 1010.08,
#    'grnd_level': 1009.9},
#   'wind': {'speed': 6.73, 'deg': 133.609},
#   'rain': {'3h': 0.75},
#   'clouds': {'all': 99},
#   'dt': 1570150470,
#   'sys': {'message': 0.0077,
#    'country': 'MV',
#    'sunrise': 1570150379,
#    'sunset': 1570193999},
#   'timezone': 18000,
#   'id': 1282256,
#   'name': 'Hithadhoo',
#   'cod': 200},
#  {'coord': {'lon': -52.87, 'lat': 68.71},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 278.205,
#    'pressure': 992,
#    'humidity': 68,
#    'temp_min': 278.205,
#    'temp_max': 278.205,
#    'sea_level': 992,
#    'grnd_level': 992.54},
#   'wind': {'speed': 9.26, 'deg': 67.876},
#   'clouds': {'all': 17},
#   'dt': 1570150470,
#   'sys': {'message': 0.0065,
#    'country': 'GL',
#    'sunrise': 1570096294,
#    'sunset': 1570135764},
#   'timezone': -7200,
#   'id': 3424901,
#   'name': 'Aasiaat',
#   'cod': 200},
#  {'coord': {'lon': -80.05, 'lat': 0.07},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 296.305,
#    'pressure': 1012.22,
#    'humidity': 87,
#    'temp_min': 296.305,
#    'temp_max': 296.305,
#    'sea_level': 1012.22,
#    'grnd_level': 1012.29},
#   'wind': {'speed': 7.39, 'deg': 207.553},
#   'clouds': {'all': 100},
#   'dt': 1570150471,
# ...
#    'temp_max': 281.15},
#   'visibility': 10000,
#   'wind': {'speed': 6.7, 'deg': 270},
#   'clouds': {'all': 0},
#   'dt': 1570150698,
#   'sys': {'type': 1,
#    'id': 8293,
#    'message': 0.0067,
#    'country': 'AR',
#    'sunrise': 1570096837,
#    'sunset': 1570143068},
#   'timezone': -10800,
#   'id': 3838859,
#   'name': 'Rio Gallegos',
#   'cod': 200},
#  {'coord': {'lon': -119.25, 'lat': 39.61},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 288.98,
#    'pressure': 1015,
#    'humidity': 19,
#    'temp_min': 284.82,
#    'temp_max': 293.15},
#   'visibility': 16093,
#   'wind': {'speed': 8.7, 'deg': 240, 'gust': 11.8},
#   'clouds': {'all': 1},
#   'dt': 1570150699,
#   'sys': {'type': 1,
#    'id': 5724,
#    'message': 0.0086,
#    'country': 'US',
#    'sunrise': 1570110889,
#    'sunset': 1570153025},
#   'timezone': -25200,
#   'id': 5504003,
#   'name': 'Fernley',
#   'cod': 200},
#  {'coord': {'lon': 60.9, 'lat': 54.65},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 282.995,
#    'pressure': 1023.07,
#    'humidity': 90,
#    'temp_min': 282.995,
#    'temp_max': 282.995,
#    'sea_level': 1023.07,
#    'grnd_level': 983.6},
#   'wind': {'speed': 2.53, 'deg': 256.973},
#   'clouds': {'all': 65},
#   'dt': 1570150699,
#   'sys': {'message': 0.0085,
#    'country': 'RU',
#    'sunrise': 1570154580,
#    'sunset': 1570195642},
#   'timezone': 18000,
#   'id': 1502280,
#   'name': 'Koyelga',
#   'cod': 200},
#  {'coord': {'lon': 24.66, 'lat': 14.2},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 296.335,
#    'pressure': 1009.98,
#    'humidity': 57,
#    'temp_min': 296.335,
#    'temp_max': 296.335,
#    'sea_level': 1009.98,
#    'grnd_level': 882.35},
#   'wind': {'speed': 4.6, 'deg': 128.285},
#   'rain': {'3h': 2.126},
#   'clouds': {'all': 97},
#   'dt': 1570150700,
#   'sys': {'message': 0.0064,
#    'country': 'SD',
#    'sunrise': 1570162257,
#    'sunset': 1570205357},
#   'timezone': 7200,
#   'id': 371745,
#   'name': 'Kutum',
#   'cod': 200},
#  {'coord': {'lon': -1.35, 'lat': 60.4},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 279.85,
#    'pressure': 1011,
#    'humidity': 93,
#    'temp_min': 278.15,
#    'temp_max': 281.15},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 100},
#   'rain': {'3h': 0.125},
#   'clouds': {'all': 40},
#   'dt': 1570150556,
#   'sys': {'type': 1,
#    'id': 1447,
#    'message': 0.0079,
#    'country': 'GB',
#    'sunrise': 1570169839,
#    'sunset': 1570210257},
#   'timezone': 3600,
#   'id': 2654970,
#   'name': 'Brae',
#   'cod': 200},
#  {'coord': {'lon': -39.92, 'lat': -2.92},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 298.315,
#    'pressure': 1013.36,
#    'humidity': 81,
#    'temp_min': 298.315,
#    'temp_max': 298.315,
#    'sea_level': 1013.36,
#    'grnd_level': 1009.28},
#   'wind': {'speed': 4.56, 'deg': 84.354},
#   'clouds': {'all': 0},
#   'dt': 1570150598,
#   'sys': {'message': 0.0074,
#    'country': 'BR',
#    'sunrise': 1570091074,
#    'sunset': 1570134770},
#   'timezone': -10800,
#   'id': 3393692,
#   'name': 'Itarema',
#   'cod': 200},
#  {'coord': {'lon': 150.85, 'lat': -34.58},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 299.06,
#    'pressure': 1017,
#    'humidity': 60,
#    'temp_min': 294.26,
#    'temp_max': 305.37},
#   'visibility': 10000,
#   'wind': {'speed': 7.7, 'deg': 160, 'gust': 12.9},
#   'clouds': {'all': 75},
#   'dt': 1570150701,
#   'sys': {'type': 1,
#    'id': 9594,
#    'message': 0.0086,
#    'country': 'AU',
#    'sunrise': 1570131010,
#    'sunset': 1570176046},
#   'timezone': 36000,
#   'id': 6255012,
#   'name': 'Flinders',
#   'cod': 200},
#  {'coord': {'lon': 122.3, 'lat': 29.96},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 297.115,
#    'pressure': 1013.39,
#    'humidity': 89,
#    'temp_min': 297.115,
#    'temp_max': 297.115,
#    'sea_level': 1013.39,
#    'grnd_level': 1011.12},
#   'wind': {'speed': 3, 'deg': 155.292},
#   'clouds': {'all': 0},
#   'dt': 1570150702,
#   'sys': {'message': 0.0057,
#    'country': 'CN',
#    'sunrise': 1570139117,
#    'sunset': 1570181640},
#   'timezone': 28800,
#   'id': 1795632,
#   'name': 'Shenjiamen',
#   'cod': 200},
#  {'coord': {'lon': -0.61, 'lat': 51.19},
#   'weather': [{'id': 310,
#     'main': 'Drizzle',
#     'description': 'light intensity drizzle rain',
#     'icon': '09n'},
#    {'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'},
#    {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 286.65,
#    'pressure': 1004,
#    'humidity': 93,
#    'temp_min': 285.37,
#    'temp_max': 288.15},
#   'visibility': 5000,
#   'wind': {'speed': 6.2, 'deg': 260, 'gust': 11.8},
#   'clouds': {'all': 100},
#   'dt': 1570150704,
#   'sys': {'type': 1,
#    'id': 1415,
#    'message': 0.0104,
#    'country': 'GB',
#    'sunrise': 1570169219,
#    'sunset': 1570210522},
#   'timezone': 3600,
#   'id': 2648372,
#   'name': 'Godalming',
#   'cod': 200},
#  {'coord': {'lon': -73.79, 'lat': 2.18},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 293.905,
#    'pressure': 1013.23,
#    'humidity': 99,
#    'temp_min': 293.905,
#    'temp_max': 293.905,
#    'sea_level': 1013.23,
#    'grnd_level': 978.51},
#   'wind': {'speed': 0.73, 'deg': 328.996},
#   'rain': {'3h': 1.937},
#   'clouds': {'all': 100},
#   'dt': 1570150704,
#   'sys': {'message': 0.0193,
#    'country': 'CO',
#    'sunrise': 1570099285,
#    'sunset': 1570142813},
#   'timezone': -18000,
#   'id': 3827693,
#   'name': 'La Macarena',
#   'cod': 200},
#  {'coord': {'lon': 55.52, 'lat': 39.24},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 287.185,
#    'pressure': 1015.89,
#    'humidity': 28,
#    'temp_min': 287.185,
#    'temp_max': 287.185,
#    'sea_level': 1015.89,
#    'grnd_level': 1014.01},
#   'wind': {'speed': 5.37, 'deg': 71.683},
#   'clouds': {'all': 0},
#   'dt': 1570150705,
#   'sys': {'message': 0.0058,
#    'country': 'TM',
#    'sunrise': 1570155364,
#    'sunset': 1570197440},
#   'timezone': 18000,
#   'id': 161974,
#   'name': 'Gazanjyk',
#   'cod': 200},
#  {'coord': {'lon': 112.4, 'lat': 66.42},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'base': 'stations',
#   'main': {'temp': 269.15,
#    'pressure': 1010,
#    'humidity': 100,
#    'temp_min': 269.15,
#    'temp_max': 269.15},
#   'visibility': 4000,
#   'wind': {'speed': 2, 'deg': 310},
#   'clouds': {'all': 90},
#   'dt': 1570150643,
#   'sys': {'type': 1,
#    'id': 8846,
#    'message': 0.007,
#    'country': 'RU',
#    'sunrise': 1570142926,
#    'sunset': 1570182582},
#   'timezone': 32400,
#   'id': 2014624,
#   'name': 'Udachnyy',
#   'cod': 200},
#  {'coord': {'lon': 112.45, 'lat': -7.54},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 300.115,
#    'pressure': 1013.73,
#    'humidity': 61,
#    'temp_min': 300.115,
#    'temp_max': 300.115,
#    'sea_level': 1013.73,
#    'grnd_level': 1000.91},
#   'wind': {'speed': 5.98, 'deg': 182.378},
#   'clouds': {'all': 0},
#   'dt': 1570150705,
#   'sys': {'message': 0.0058,
#    'country': 'ID',
#    'sunrise': 1570140810,
#    'sunset': 1570184675},
#   'timezone': 25200,
#   'id': 1635111,
#   'name': 'Puri',
#   'cod': 200},
#  {'coord': {'lon': 49.38, 'lat': -18.17},
#   'weather': [{'id': 521,
#     'main': 'Rain',
#     'description': 'shower rain',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 294.15,
#    'pressure': 1019,
#    'humidity': 94,
#    'temp_min': 294.15,
#    'temp_max': 294.15},
#   'visibility': 10000,
#   'wind': {'speed': 0.72, 'deg': 248.658},
#   'clouds': {'all': 40},
#   'dt': 1570150706,
#   'sys': {'type': 1,
#    'id': 2139,
#    'message': 0.0066,
#    'country': 'MG',
#    'sunrise': 1570155735,
#    'sunset': 1570200016},
#   'timezone': 10800,
#   'id': 1053384,
#   'name': 'Toamasina',
#   'cod': 200},
#  {'coord': {'lon': 151.26, 'lat': -23.84},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 298.34,
#    'pressure': 1024,
#    'humidity': 41,
#    'temp_min': 297.15,
#    'temp_max': 299.26},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 100},
#   'clouds': {'all': 0},
#   'dt': 1570150706,
#   'sys': {'type': 1,
#    'id': 9526,
#    'message': 0.0111,
#    'country': 'AU',
#    'sunrise': 1570131178,
#    'sunset': 1570175681},
#   'timezone': 36000,
#   'id': 2165478,
#   'name': 'Gladstone',
#   'cod': 200},
#  {'coord': {'lon': 153.24, 'lat': -28.95},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 298.59,
#    'pressure': 1022,
#    'humidity': 36,
#    'temp_min': 297.15,
#    'temp_max': 299.82},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 350},
#   'clouds': {'all': 0},
#   'dt': 1570150666,
#   'sys': {'type': 1,
#    'id': 9537,
#    'message': 0.0068,
#    'country': 'AU',
#    'sunrise': 1570130585,
#    'sunset': 1570175325},
#   'timezone': 36000,
#   'id': 2160063,
#   'name': 'Codrington',
#   'cod': 200},
#  {'coord': {'lon': 7.07, 'lat': 5.43},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 295.505,
#    'pressure': 1011.1,
#    'humidity': 98,
#    'temp_min': 295.505,
#    'temp_max': 295.505,
#    'sea_level': 1011.1,
#    'grnd_level': 1001.28},
#   'wind': {'speed': 1.77, 'deg': 209.391},
#   'clouds': {'all': 94},
#   'dt': 1570150655,
#   'sys': {'message': 0.0073,
#    'country': 'NG',
#    'sunrise': 1570166324,
#    'sunset': 1570209732},
#   'timezone': 3600,
#   'id': 2337542,
#   'name': 'Naze',
#   'cod': 200},
#  {'coord': {'lon': -10.8, 'lat': 6.33},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 298.15,
#    'pressure': 1013,
#    'humidity': 94,
#    'temp_min': 298.15,
#    'temp_max': 298.15},
#   'visibility': 10000,
#   'wind': {'speed': 2.84, 'deg': 211.404},
#   'clouds': {'all': 75},
#   'dt': 1570150708,
#   'sys': {'type': 1,
#    'id': 2389,
#    'message': 0.0079,
#    'country': 'LR',
#    'sunrise': 1570170628,
#    'sunset': 1570214003},
#   'timezone': 0,
#   'id': 2274895,
#   'name': 'Monrovia',
#   'cod': 200},
#  {'coord': {'lon': -79.15, 'lat': -7.84},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50n'}],
#   'base': 'stations',
#   'main': {'temp': 290.15,
#    'pressure': 1016,
#    'humidity': 88,
#    'temp_min': 290.15,
#    'temp_max': 290.15},
#   'visibility': 7000,
#   'wind': {'speed': 4.1, 'deg': 150},
#   'clouds': {'all': 75},
#   'dt': 1570150708,
#   'sys': {'type': 1,
#    'id': 8690,
#    'message': 0.0056,
#    'country': 'PE',
#    'sunrise': 1570100403,
#    'sunset': 1570144267},
#   'timezone': -18000,
#   'id': 3698359,
#   'name': 'Chicama',
#   'cod': 200},
#  {'coord': {'lon': 87.76, 'lat': 69.35},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 277.15,
#    'pressure': 996,
#    'humidity': 86,
#    'temp_min': 277.15,
#    'temp_max': 277.15},
#   'visibility': 10000,
#   'wind': {'speed': 8, 'deg': 140},
#   'clouds': {'all': 75},
#   'dt': 1570150708,
#   'sys': {'type': 1,
#    'id': 8951,
#    'message': 0.008,
#    'country': 'RU',
#    'sunrise': 1570149150,
#    'sunset': 1570188183},
#   'timezone': 25200,
#   'id': 1497337,
#   'name': 'Kayerkan',
#   'cod': 200},
#  {'coord': {'lon': -76.9, 'lat': 34.88},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 299.62,
#    'pressure': 1015,
#    'humidity': 83,
#    'temp_min': 298.71,
#    'temp_max': 300.37},
#   'visibility': 14484,
#   'wind': {'speed': 2.6, 'deg': 200},
#   'clouds': {'all': 1},
#   'dt': 1570150709,
#   'sys': {'type': 1,
#    'id': 5098,
#    'message': 0.0085,
#    'country': 'US',
#    'sunrise': 1570100611,
#    'sunset': 1570142980},
#   'timezone': -14400,
#   'id': 4470244,
#   'name': 'Havelock',
#   'cod': 200},
#  {'coord': {'lon': 75.32, 'lat': 51.72},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 280.965,
#    'pressure': 1026.03,
#    'humidity': 38,
#    'temp_min': 280.965,
#    'temp_max': 280.965,
#    'sea_level': 1026.03,
#    'grnd_level': 1005.23},
#   'wind': {'speed': 3.31, 'deg': 241.082},
#   'clouds': {'all': 72},
#   'dt': 1570150709,
#   'sys': {'message': 0.0054,
#    'country': 'KZ',
#    'sunrise': 1570150995,
#    'sunset': 1570192307},
#   'timezone': 21600,
#   'id': 1524325,
#   'name': 'Ekibastuz',
#   'cod': 200},
#  {'coord': {'lon': 78.7, 'lat': 67.47},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 278.425,
#    'pressure': 992.37,
#    'humidity': 97,
#    'temp_min': 278.425,
#    'temp_max': 278.425,
#    'sea_level': 992.37,
#    'grnd_level': 990.97},
#   'wind': {'speed': 4.4, 'deg': 220.729},
#   'rain': {'3h': 1.063},
#   'clouds': {'all': 100},
#   'dt': 1570150710,
#   'sys': {'message': 0.0062,
#    'country': 'RU',
#    'sunrise': 1570151131,
#    'sunset': 1570190550},
#   'timezone': 18000,
#   'id': 1489853,
#   'name': 'Tazovskiy',
#   'cod': 200},
#  {'coord': {'lon': 18.15, 'lat': -26.57},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 289.15,
#    'pressure': 1022,
#    'humidity': 21,
#    'temp_min': 289.15,
#    'temp_max': 289.15},
#   'wind': {'speed': 3.1, 'deg': 230},
#   'clouds': {'all': 0},
#   'dt': 1570150710,
#   'sys': {'type': 1,
#    'id': 2264,
#    'message': 0.0068,
#    'country': 'NA',
#    'sunrise': 1570163038,
#    'sunset': 1570207700},
#   'timezone': 7200,
#   'id': 3356264,
#   'name': 'Keetmanshoop',
#   'cod': 200},
#  {'coord': {'lon': 21.24, 'lat': -28.46},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 288.15,
#    'pressure': 1019,
#    'humidity': 21,
#    'temp_min': 288.15,
#    'temp_max': 288.15},
#   'visibility': 10000,
#   'wind': {'speed': 1, 'deg': 190},
#   'clouds': {'all': 0},
#   'dt': 1570150711,
#   'sys': {'type': 1,
#    'id': 1990,
#    'message': 0.0055,
#    'country': 'ZA',
#    'sunrise': 1570162251,
#    'sunset': 1570207004},
#   'timezone': 7200,
#   'id': 945945,
#   'name': 'Upington',
#   'cod': 200},
#  {'coord': {'lon': -5.93, 'lat': 54.6},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 285.12,
#    'pressure': 997,
#    'humidity': 93,
#    'temp_min': 284.82,
#    'temp_max': 285.37},
#   'visibility': 7000,
#   'wind': {'speed': 3.1, 'deg': 160},
#   'clouds': {'all': 100},
#   'dt': 1570150645,
#   'sys': {'type': 1,
#    'id': 1376,
#    'message': 0.0068,
#    'country': 'GB',
#    'sunrise': 1570170638,
#    'sunset': 1570211656},
#   'timezone': 3600,
#   'id': 2655984,
#   'name': 'Belfast',
#   'cod': 200},
#  {'coord': {'lon': 6.81, 'lat': 61.84},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 275.38,
#    'pressure': 999,
#    'humidity': 94,
#    'temp_min': 272.59,
#    'temp_max': 277.59},
#   'wind': {'speed': 0.45, 'deg': 207, 'gust': 2.68},
#   'clouds': {'all': 0},
#   'dt': 1570150712,
#   'sys': {'type': 3,
#    'id': 2007194,
#    'message': 0.0064,
#    'country': 'NO',
#    'sunrise': 1570167969,
#    'sunset': 1570208211},
#   'timezone': 7200,
#   'id': 3135601,
#   'name': 'Olden',
#   'cod': 200}]

# %%
# Normalize weather data so columns with dictionary values are flattened.
normalized_df = json_normalize(response)

# Create new df that only displays necessary columns for analysis.
## Sys column not showing, need to show country
clean_df = normalized_df.filter(items=['coord.lat', 'coord.lon', 'main.temp_max','main.humidity', 'weather', 'wind.speed', 'sys', 'name'])
clean_df.head()
# Out:
#    coord.lat  coord.lon  main.temp_max  main.humidity  \
# 0      52.11    -101.27        276.335             80
# 1      45.36     -73.48        282.150             70
# 2     -33.93      18.42        288.710             93
# 3     -22.97     -42.02        295.150             88
# 4     -34.53      20.04        288.710             82
#
#                                              weather  wind.speed  \
# 0  [{'id': 803, 'main': 'Clouds', 'description': ...        2.39
# 1  [{'id': 500, 'main': 'Rain', 'description': 'l...        4.10
# 2  [{'id': 803, 'main': 'Clouds', 'description': ...        3.10
# 3  [{'id': 802, 'main': 'Clouds', 'description': ...        6.20
# 4  [{'id': 801, 'main': 'Clouds', 'description': ...        1.50
#
#               name
# 0       Swan River
# 1   Saint-Philippe
# 2        Cape Town
# 3  Arraial do Cabo
# 4       Bredasdorp

# %%
clean_df.head()
# Out:
#    coord.lat  coord.lon  main.temp_max  main.humidity  \
# 0      52.11    -101.27        276.335             80
# 1      45.36     -73.48        282.150             70
# 2     -33.93      18.42        288.710             93
# 3     -22.97     -42.02        295.150             88
# 4     -34.53      20.04        288.710             82
#
#                                              weather  wind.speed  \
# 0  [{'id': 803, 'main': 'Clouds', 'description': ...        2.39
# 1  [{'id': 500, 'main': 'Rain', 'description': 'l...        4.10
# 2  [{'id': 803, 'main': 'Clouds', 'description': ...        3.10
# 3  [{'id': 802, 'main': 'Clouds', 'description': ...        6.20
# 4  [{'id': 801, 'main': 'Clouds', 'description': ...        1.50
#
#               name
# 0       Swan River
# 1   Saint-Philippe
# 2        Cape Town
# 3  Arraial do Cabo
# 4       Bredasdorp

# %%
split_weather = json_normalize(response, ['weather'])

# %%
split_weather.head()
# Out:
#         description icon   id    main
# 0     broken clouds  04n  803  Clouds
# 1        light rain  10n  500    Rain
# 2     broken clouds  04n  803  Clouds
# 3  scattered clouds  03n  802  Clouds
# 4        few clouds  02n  801  Clouds

# %%
clean_df['main'] = split_weather['main']
clean_df['main_id'] = split_weather['id']
clean_df.head(20)
# Out:
#     coord.lat  coord.lon  main.temp_max  main.humidity  \
# 0       52.11    -101.27        276.335             80
# 1       45.36     -73.48        282.150             70
# 2      -33.93      18.42        288.710             93
# 3      -22.97     -42.02        295.150             88
# 4      -34.53      20.04        288.710             82
# 5       51.76      48.54        285.715             79
# 6      -42.48     -73.76        281.150             75
# 7       69.70     170.27        272.795             84
# 8      -21.55     167.88        293.855             71
# 9       -1.80     -53.48        301.455             59
# 10     -15.19      12.15        291.605             81
# 11      22.08    -159.32        304.150             70
# 12     -46.19     168.86        289.260             60
# 13      67.56      30.47        270.695             96
# 14     -38.31     -60.23        280.125             60
# 15     -53.16     -70.91        279.150             70
# 16     -31.43     152.91        302.150             28
# 17      72.79     -56.15        276.525             74
# 18      69.44    -133.03        275.150            100
# 19      60.55    -151.26        285.150             54
#
#                                               weather  wind.speed  \
# 0   [{'id': 803, 'main': 'Clouds', 'description': ...        2.39
# 1   [{'id': 500, 'main': 'Rain', 'description': 'l...        4.10
# 2   [{'id': 803, 'main': 'Clouds', 'description': ...        3.10
# 3   [{'id': 802, 'main': 'Clouds', 'description': ...        6.20
# 4   [{'id': 801, 'main': 'Clouds', 'description': ...        1.50
# 5   [{'id': 803, 'main': 'Clouds', 'description': ...        3.84
# 6   [{'id': 800, 'main': 'Clear', 'description': '...        3.60
# 7   [{'id': 804, 'main': 'Clouds', 'description': ...        5.67
# 8   [{'id': 804, 'main': 'Clouds', 'description': ...        8.23
# 9   [{'id': 803, 'main': 'Clouds', 'description': ...        1.39
# 10  [{'id': 803, 'main': 'Clouds', 'description': ...        3.69
# 11  [{'id': 501, 'main': 'Rain', 'description': 'm...        7.20
# 12  [{'id': 804, 'main': 'Clouds', 'description': ...        4.92
# 13  [{'id': 800, 'main': 'Clear', 'description': '...        0.94
# 14  [{'id': 804, 'main': 'Clouds', 'description': ...        5.07
# 15  [{'id': 803, 'main': 'Clouds', 'description': ...        5.10
# 16  [{'id': 800, 'main': 'Clear', 'description': '...        1.50
# 17  [{'id': 804, 'main': 'Clouds', 'description': ...        4.00
# 18  [{'id': 701, 'main': 'Mist', 'description': 'm...        3.60
# 19  [{'id': 802, 'main': 'Clouds', 'description': ...        1.35
#
#                name    main  main_id
# 0        Swan River  Clouds      803
# 1    Saint-Philippe    Rain      500
# 2         Cape Town  Clouds      803
# 3   Arraial do Cabo  Clouds      802
# 4        Bredasdorp  Clouds      801
# 5            Gornyy  Clouds      803
# 6            Castro   Clear      800
# 7             Pevek  Clouds      804
# 8            Tadine  Clouds      804
# 9           Prainha  Clouds      803
# 10           Namibe  Clouds      803
# 11            Kapaa    Rain      501
# 12          Mataura  Clouds      804
# 13           Kovdor   Clear      800
# 14           Barrow  Clouds      804
# 15     Punta Arenas  Clouds      803
# 16   Port Macquarie   Clear      800
# 17        Upernavik  Clouds      804
# 18      Tuktoyaktuk    Mist      701
# 19            Kenai  Clouds      802

# %%
df.to_csv(output_data_file) # Possibly change to final cleaned df

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
date = input("Insert today's date (mm/dd/yyyy): ")
temp_fig = clean_df.plot.scatter('coord.lat', 'main.temp_max')
plt.title(f"Latitude vs Temperature as of {date}")
temp_fig.set_xlabel("Latitude")
temp_fig.set_ylabel("Temperature")
plt.savefig('output_data/temp.png')
# Out:
# Insert today's date (mm/dd/yyyy): 10/03/2019

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
temp_fig = clean_df.plot.scatter('coord.lat', 'main.humidity')
plt.title(f"Latitude vs Humidity as of {date}")
temp_fig.set_xlabel("Latitude")
temp_fig.set_ylabel("Humidity")
plt.savefig('output_data/humid.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
temp_fig = clean_df.plot.scatter('coord.lat', 'main_id')
plt.title(f"Latitude vs Cloudiness as of {date}")
temp_fig.set_xlabel("Latitude")
temp_fig.set_ylabel("Cloudiness")
plt.savefig('output_data/cloud.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
temp_fig = clean_df.plot.scatter('coord.lat', 'wind.speed')
plt.title(f"Latitude vs Wind as of {date}")
temp_fig.set_xlabel("Latitude")
temp_fig.set_ylabel("Speed of wind")
plt.savefig('output_data/wind.png')

# %%
to_html(df)
